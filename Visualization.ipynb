# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data_cleaned.csv')

# %%
data=data.drop(['country','year'],axis=1)

# %%
data.head()
# Out:
#    cereal_yield  fdi_perc_gdp  en_per_gdp    en_per_cap     co2_ttl  \
# 0         417.4      5.449515  179.271884    565.451027    4367.397
# 1        1594.0      0.076475  245.977706  12262.388130   57010.849
# 2        2666.1      1.285579  173.122857   1434.960601  117021.304
# 3        1603.3      1.306912  208.686644   4926.727783  281530.258
# 4        5463.0      0.209142  128.939160   3381.073790   65888.656
#
#    co2_per_cap  co2_per_gdp  pop_urb_aggl_perc  prot_area_perc           gdp  \
# 0     0.409949   129.971142          15.290728       12.399822  1.219375e+10
# 1    29.851550   598.807980          26.377204        0.266886  3.391964e+10
# 2     3.536073   426.614517          39.119646        4.772468  1.897200e+11
# 3    16.288490   689.948873          60.356798        7.915273  3.299655e+11
# 4     8.448456   322.186648          19.746121       20.991143  1.721664e+11
#
#    gni_per_cap  under_5_mort_rate  pop_growth_perc         pop  \
# 0        820.0              239.1         3.034866  10653515.0
# 1      19340.0               20.5         5.442852   1909812.0
# 2       3960.0               25.8         1.372593  33093579.0
# 3      18380.0                8.6         1.274577  17284000.0
# 4      21200.0                8.9         1.134999   7798899.0
#
#    urb_pop_growth_perc       urb_pop        en_ttl
# 0             6.687032  4.099473e+06  2.185996e+09
# 1             5.265704  1.507988e+06  8.343475e+09
# 2             1.762636  2.890393e+07  3.284487e+10
# 3             1.438378  1.478473e+07  6.885939e+10
# 4             1.134999  5.131676e+06  2.219899e+10

# %%
data.shape
# Out:
# (1700, 17)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   cereal_yield         1700 non-null   float64
#  1   fdi_perc_gdp         1700 non-null   float64
#  2   en_per_gdp           1700 non-null   float64
#  3   en_per_cap           1700 non-null   float64
#  4   co2_ttl              1700 non-null   float64
#  5   co2_per_cap          1700 non-null   float64
#  6   co2_per_gdp          1700 non-null   float64
#  7   pop_urb_aggl_perc    1700 non-null   float64
#  8   prot_area_perc       1700 non-null   float64
#  9   gdp                  1700 non-null   float64
#  10  gni_per_cap          1700 non-null   float64
#  11  under_5_mort_rate    1700 non-null   float64
#  12  pop_growth_perc      1700 non-null   float64
#  13  pop                  1700 non-null   float64
#  14  urb_pop_growth_perc  1700 non-null   float64
#  15  urb_pop              1700 non-null   float64
#  16  en_ttl               1700 non-null   float64
# dtypes: float64(17)
# memory usage: 225.9 KB

# %%
data.describe()
# Out:
#               year  cereal_yield  fdi_perc_gdp   en_per_gdp    en_per_cap  \
# count  1700.000000   1700.000000   1700.000000  1700.000000   1700.000000
# mean   1999.570588   3013.317581      2.948940   249.822736   1968.979736
# std       5.143070   1796.206082      3.949722   186.195019   1959.419972
# min    1991.000000    175.700000    -15.027675    66.335372    116.511476
# 25%    1995.000000   1683.364736      0.834105   136.320490    542.882788
# 50%    2000.000000   2584.800000      1.993220   197.624918   1089.225939
# 75%    2004.000000   3933.400000      3.702149   286.474936   2893.996077
# max    2008.000000   8410.800000     51.373951  1383.380011  12607.839262
#
#             co2_ttl  co2_per_cap  co2_per_gdp  pop_urb_aggl_perc  \
# count  1.700000e+03  1700.000000  1700.000000        1700.000000
# mean   9.793999e+05     4.676663   482.303784          21.480126
# std    3.235692e+06     4.906273   392.192230          12.105158
# min    7.077310e+02     0.029411    45.552592           3.526316
# 25%    1.462125e+04     0.922769   257.139562          12.383953
# 50%    7.728386e+04     3.093346   368.415567          18.525960
# 75%    3.708446e+05     7.441195   586.972993          28.988324
# max    3.064936e+07    37.106499  3343.454250          60.505780
#
#        prot_area_perc           gdp   gni_per_cap  under_5_mort_rate  \
# count     1700.000000  1.700000e+03   1700.000000        1700.000000
# mean        12.201789  1.058568e+12   7898.668664          51.971955
# std          9.116682  3.921323e+12  11592.516937          51.332162
# min          0.000000  9.826326e+08     80.000000           3.200000
# 25%          5.839844  1.636221e+10    780.000000          10.000000
# 50%         10.293791  9.882942e+10   2150.770301          32.350000
# 75%         16.599298  4.122600e+11   9205.000000          79.925741
# max         53.749825  5.580488e+13  58620.000000         239.100000
#
#        pop_growth_perc           pop  urb_pop_growth_perc       urb_pop
# count      1700.000000  1.700000e+03          1700.000000  1.700000e+03
# mean          1.451313  3.060142e+08             2.252231  1.347903e+08
# std           1.129312  9.482329e+08             1.642009  4.145755e+08
# min          -2.397174  1.909812e+06            -2.757210  1.151309e+06
# 25%           0.630306  9.973065e+06             0.925308  5.469794e+06
# 50%           1.519890  2.689207e+07             2.315122  1.423239e+07
# 75%           2.276853  8.234386e+07             3.364747  4.835246e+07
# max          11.180657  6.610030e+09            12.829046  3.264974e+09

# %%
data['en_ttl'] = data['en_per_gdp'] * data['gdp'] /1000

# %%
features_all = data[['country','year','cereal_yield','fdi_perc_gdp','gni_per_cap', 'en_per_gdp', 'en_per_cap', 'en_ttl', 'co2_ttl', 'co2_per_cap', 'co2_per_gdp', 'pop_urb_aggl_perc', 'prot_area_perc', 'gdp',  'pop_growth_perc', 'pop', 'urb_pop_growth_perc']]


sns.set(font_scale=2)
f,ax=plt.subplots(figsize=(30,20))
sns.heatmap(features_all.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation between features', fontsize=25, weight='bold' )
plt.show()

sns.set(font_scale=1)
